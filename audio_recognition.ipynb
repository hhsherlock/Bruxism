# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Dec 19

@author: yaning
"""

import librosa
import numpy as np
import matplotlib.pyplot as plt

path = "/home/yaning/Documents/"

# %%
y, sr = librosa.load(path+"sleep_audios/test.wav", sr=None, mono=True)

# %%
y.shape
# Out:
# (40118400,)

# %%
sr
# Out:
# 44100

# %%
plt.plot(y)
# plt.ylim(-0.5,0.5)

# %%
print(sr, y.shape)
# Out:
# 44100 (21192192,)
